# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
#path fixing
df = pd.read_csv(r"C:\Users\sebar\Downloads\weather_forecast_data.csv")
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0       23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1       27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2       25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3       23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4       20.591370  96.858822    4.643921    47.676444   980.825142  no rain
# ...           ...        ...         ...          ...          ...      ...
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain
#
# [2500 rows x 6 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0       23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1       27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2       25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3       23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4       20.591370  96.858822    4.643921    47.676444   980.825142  no rain
# ...           ...        ...         ...          ...          ...      ...
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain
#
# [2500 rows x 6 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0       23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1       27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2       25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3       23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4       20.591370  96.858822    4.643921    47.676444   980.825142  no rain
# ...           ...        ...         ...          ...          ...      ...
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain
#
# [2500 rows x 6 columns]>

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind_Speed', 'Cloud_Cover', 'Pressure',
#        'Rain'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1    27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2    25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3    23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4    20.591370  96.858822    4.643921    47.676444   980.825142  no rain
# 5    26.147353  48.217260   15.258547    59.766279  1049.738751  no rain
# 6    20.939680  40.799444    2.232566    45.827508  1014.173766  no rain
# 7    32.294325  51.848471    2.873621    92.551497  1006.041733  no rain
# 8    34.091569  48.057114    5.570206    82.524873   993.732047  no rain
# 9    19.586038  82.978293    5.760537    98.014450  1036.503457     rain

# %%
df.tail(10)
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 2490    27.365273  43.619778    3.390757    69.498333   980.694046  no rain
# 2491    11.081767  45.470035   14.397602    19.460689  1032.905052  no rain
# 2492    30.019013  46.479933    6.393025    11.403676   994.319633  no rain
# 2493    19.435755  40.699514   14.033566    26.211576  1010.480761  no rain
# 2494    26.755974  78.504229    0.457207    73.550223   986.482791  no rain
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Humidity       0
# Wind_Speed     0
# Cloud_Cover    0
# Pressure       0
# Rain           0
# dtype: int64

# %%
df.dtypes
# Out:
# Temperature    float64
# Humidity       float64
# Wind_Speed     float64
# Cloud_Cover    float64
# Pressure       float64
# Rain            object
# dtype: object

# %%
df[['Temperature', 'Humidity']].describe()
# Out:
#        Temperature     Humidity
# count  2500.000000  2500.000000
# mean     22.581725    64.347094
# std       7.326996    19.954739
# min      10.001842    30.005071
# 25%      16.359398    47.339815
# 50%      22.536448    63.920797
# 75%      28.976476    81.561021
# max      34.995214    99.997481

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load the dataset
file_path = r"C:\Users\sebar\Downloads\weather_forecast_data.csv"  # Replace with your file path
weather_data = pd.read_csv(file_path)

# Encoding the target variable
le = LabelEncoder()
weather_data['Rain'] = le.fit_transform(weather_data['Rain'])

# Splitting dataset into features and target variable
X = weather_data.drop('Rain', axis=1)
y = weather_data['Rain']

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)





# Scaling features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Logistic Regression Model
log_reg = LogisticRegression()
log_reg.fit(X_train_scaled, y_train)
log_reg_pred = log_reg.predict(X_test_scaled)

# Evaluating Logistic Regression
print("Logistic Regression Metrics:")
print(f"  Accuracy: {accuracy_score(y_test, log_reg_pred):.2f}")
print(f"  Precision: {precision_score(y_test, log_reg_pred):.2f}")
print(f"  Recall: {recall_score(y_test, log_reg_pred):.2f}")
print(f"  F1 Score: {f1_score(y_test, log_reg_pred):.2f}")
print(f"  Confusion Matrix:\n{confusion_matrix(y_test, log_reg_pred)}")
# Out:
# Logistic Regression Metrics:
#   Accuracy: 0.91
#   Precision: 0.71
#   Recall: 0.56
#   F1 Score: 0.63
#   Confusion Matrix:
# [[1895   65]
#  [ 128  162]]

# %%
# Importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load the dataset
file_path = r"C:\Users\sebar\Downloads\weather_forecast_data.csv"  # Replace with your file path
weather_data = pd.read_csv(file_path)

# Encoding the target variable
le = LabelEncoder()
weather_data['Rain'] = le.fit_transform(weather_data['Rain'])

# Splitting dataset into features and target variable
X = weather_data.drop('Rain', axis=1)
y = weather_data['Rain']

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42)

# Scaling features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Support Vector Classifier (SVC) Model
svc_clf = SVC(kernel='linear', probability=True)
svc_clf.fit(X_train_scaled, y_train)
svc_clf_pred = svc_clf.predict(X_test_scaled)

# Evaluating SVC
print("Support Vector Classifier Metrics:")
print(f"  Accuracy: {accuracy_score(y_test, svc_clf_pred):.2f}")
print(f"  Precision: {precision_score(y_test, svc_clf_pred):.2f}")
print(f"  Recall: {recall_score(y_test, svc_clf_pred):.2f}")
print(f"  F1 Score: {f1_score(y_test, svc_clf_pred):.2f}")
print(f"  Confusion Matrix:\n{confusion_matrix(y_test, svc_clf_pred)}")
# Out:
# Support Vector Classifier Metrics:
#   Accuracy: 0.92
#   Precision: 0.75
#   Recall: 0.61
#   F1 Score: 0.67
#   Confusion Matrix:
# [[1902   58]
#  [ 114  176]]

# %%
# Importing libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load the dataset
file_path = r"C:\Users\sebar\Downloads\weather_forecast_data.csv"  # Replace with your file path
weather_data = pd.read_csv(file_path)

# Encoding the target variable
le = LabelEncoder()
weather_data['Rain'] = le.fit_transform(weather_data['Rain'])

# Splitting dataset into features and target variable
X = weather_data.drop('Rain', axis=1)
y = weather_data['Rain']

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scaling features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# K-Nearest Neighbors Model
knn_clf = KNeighborsClassifier(n_neighbors=5)
knn_clf.fit(X_train_scaled, y_train)
knn_pred = knn_clf.predict(X_test_scaled)

# Evaluating K-Nearest Neighbors
print("K-Nearest Neighbors Metrics:")
print(f"  Accuracy: {accuracy_score(y_test, knn_pred):.2f}")
print(f"  Precision: {precision_score(y_test, knn_pred):.2f}")
print(f"  Recall: {recall_score(y_test, knn_pred):.2f}")
print(f"  F1 Score: {f1_score(y_test, knn_pred):.2f}")
print(f"  Confusion Matrix:\n{confusion_matrix(y_test, knn_pred)}")
# Out:
# K-Nearest Neighbors Metrics:
#   Accuracy: 0.97
#   Precision: 0.87
#   Recall: 0.85
#   F1 Score: 0.86
#   Confusion Matrix:
# [[651  11]
#  [ 13  75]]

# %%
# Importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load the dataset
file_path = r"C:\Users\sebar\Downloads\weather_forecast_data.csv"  # Replace with your file path
weather_data = pd.read_csv(file_path)

# Encoding the target variable
le = LabelEncoder()
weather_data['Rain'] = le.fit_transform(weather_data['Rain'])

# Splitting dataset into features and target variable
X = weather_data.drop('Rain', axis=1)
y = weather_data['Rain']

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scaling features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Gradient Boosting Model
gb_clf = GradientBoostingClassifier(random_state=42)
gb_clf.fit(X_train_scaled, y_train)
gb_pred = gb_clf.predict(X_test_scaled)

# Evaluating Gradient Boosting
print("Gradient Boosting Metrics:")
print(f"  Accuracy: {accuracy_score(y_test, gb_pred):.2f}")
print(f"  Precision: {precision_score(y_test, gb_pred):.2f}")
print(f"  Recall: {recall_score(y_test, gb_pred):.2f}")
print(f"  F1 Score: {f1_score(y_test, gb_pred):.2f}")
print(f"  Confusion Matrix:\n{confusion_matrix(y_test, gb_pred)}")
# Out:
# Gradient Boosting Metrics:
#   Accuracy: 1.00
#   Precision: 1.00
#   Recall: 1.00
#   F1 Score: 1.00
#   Confusion Matrix:
# [[662   0]
#  [  0  88]]

# %%
# Importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load the dataset
file_path = r"C:\Users\sebar\Downloads\weather_forecast_data.csv"  # Replace with your file path
weather_data = pd.read_csv(file_path)

# Encoding the target variable
le = LabelEncoder()
weather_data['Rain'] = le.fit_transform(weather_data['Rain'])

# Splitting dataset into features and target variable
X = weather_data.drop('Rain', axis=1)
y = weather_data['Rain']

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scaling features (optional for Naive Bayes, as it handles raw features)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Naive Bayes Model
nb_clf = GaussianNB()
nb_clf.fit(X_train_scaled, y_train)
nb_pred = nb_clf.predict(X_test_scaled)

# Evaluating Naive Bayes
print("Naive Bayes Metrics:")
print(f"  Accuracy: {accuracy_score(y_test, nb_pred):.2f}")
print(f"  Precision: {precision_score(y_test, nb_pred):.2f}")
print(f"  Recall: {recall_score(y_test, nb_pred):.2f}")
print(f"  F1 Score: {f1_score(y_test, nb_pred):.2f}")
print(f"  Confusion Matrix:\n{confusion_matrix(y_test, nb_pred)}")
# Out:
# Naive Bayes Metrics:
#   Accuracy: 0.96
#   Precision: 1.00
#   Recall: 0.68
#   F1 Score: 0.81
#   Confusion Matrix:
# [[662   0]
#  [ 28  60]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = r"C:\Users\sebar\Downloads\weather_forecast_data.csv"  # Replace with your file path
weather_data = pd.read_csv(file_path)
weather_data
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0       23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1       27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2       25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3       23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4       20.591370  96.858822    4.643921    47.676444   980.825142  no rain
# ...           ...        ...         ...          ...          ...      ...
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain
#
# [2500 rows x 6 columns]

# %%
# Plotting histograms for Temperature, Humidity, Wind Speed, and Pressure
plt.figure(figsize=(15, 10))
features = ['Temperature', 'Humidity', 'Wind_Speed', 'Pressure']

for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i)
    sns.histplot(weather_data[feature], kde=True, bins=30, color='skyblue')
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Pair plot with 'Rain' as hue
sns.pairplot(weather_data, hue='Rain', palette='coolwarm')
plt.suptitle('Pair Plot of Weather Data', y=1.02)
plt.show()

# %%
# Box plot of Temperature and Humidity by Rain
plt.figure(figsize=(12, 5))

# Box plot for Temperature
plt.subplot(1, 2, 1)
sns.boxplot(x='Rain', y='Temperature', data=weather_data, palette='Set2')
plt.title('Temperature Distribution by Rain')

# Box plot for Humidity
plt.subplot(1, 2, 2)
sns.boxplot(x='Rain', y='Humidity', data=weather_data, palette='Set2')
plt.title('Humidity Distribution by Rain')

plt.tight_layout()
plt.show()

# %%
# Scatter plot of Temperature vs Humidity
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Temperature', y='Humidity', hue='Rain', data=weather_data, palette='coolwarm')
plt.title('Temperature vs Humidity')
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.legend(title='Rain')
plt.show()

# %%
# Line plot of Temperature and Humidity over time (index)
plt.figure(figsize=(12, 6))

# Temperature line plot
plt.plot(weather_data['Temperature'], label='Temperature', color='tomato')
plt.plot(weather_data['Humidity'], label='Humidity', color='skyblue')

plt.title('Temperature and Humidity Over Time')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Count plot of Rainy vs Non-Rainy days
plt.figure(figsize=(6, 4))
sns.countplot(x='Rain', data=weather_data, palette='Set2')
plt.title('Count of Rainy vs Non-Rainy Days')
plt.xlabel('Rain')
plt.ylabel('Count')
plt.show()
